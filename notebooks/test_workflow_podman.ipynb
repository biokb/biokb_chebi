# %%
from biokb_chebi.db.manager import DbManager
from biokb_chebi.rdf.turtle import TurtleCreator
from biokb_chebi.rdf.neo4j_importer import Neo4jImporter
from sqlalchemy import create_engine
import os

# %%
# to make sure no environment variable is set
os.environ.pop("CONNECTION_STR", None)
os.environ.pop("NEO4J_USER", None)
os.environ.pop("NEO4J_PASSWORD", None)
os.environ.pop("NEO4J_URI", None)

# %% [markdown]
# # Test the workflow with podman-compose

# %% [markdown]
# In production you should copy `.env_template` to `.env` and change passwords! For testing we are using `.env_template`.
#
# ```bash
# podman-compose -f docker-compose.db_neo.yml --env-file .env_template up -d
# ```
#
# **Tipp:** Before running the following command, please close all other applications that might use significant system resources, as running containers can be resource-intensive.

# %%
engine = create_engine("mysql+pymysql://biokb_user:biokb_password@localhost:3306/biokb")

DbManager(engine).import_data(keep_files=True)
TurtleCreator(engine).create_ttls()

# %% [markdown]
# Open Neo4j [browser](http://localhost:7474), login with neo4j/neo4j_password

# %%
# to make sure no environment variable is used
os.environ.pop("NEO4J_URI", None)
os.environ.pop("NEO4J_USER", None)
os.environ.pop("NEO4J_PASSWORD", None)
Neo4jImporter().import_ttls()
# Out:
# 2026-01-06 18:48:40,969 - biokb_chebi.rdf.neo4j_importer - INFO - Start importing all turtle file in Neo4J.
# 2026-01-06 18:48:40,970 - biokb_chebi.rdf.neo4j_importer - INFO - Delete an existing graph in Neo4J with node label DbChEBI.
# 2026-01-06 18:48:57,766 - neo4j.notifications - INFO - Received notification from DBMS server: <GqlStatusObject gql_status='00NA0', status_description="note: successful completion - index or constraint already exists. The command 'CREATE CONSTRAINT n10s_unique_uri IF NOT EXISTS FOR (e:Resource) REQUIRE (e.uri) IS UNIQUE' has no effect. The index or constraint specified by 'CONSTRAINT n10s_unique_uri FOR (e:Resource) REQUIRE (e.uri) IS UNIQUE' already exists.", position=None, raw_classification='SCHEMA', classification=<NotificationClassification.SCHEMA: 'SCHEMA'>, raw_severity='INFORMATION', severity=<NotificationSeverity.INFORMATION: 'INFORMATION'>, diagnostic_record={'_classification': 'SCHEMA', '_severity': 'INFORMATION', 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CREATE CONSTRAINT n10s_unique_uri IF NOT EXISTS FOR (r:Resource) REQUIRE r.uri IS UNIQUE'
# Uniqueness constraint on :Resource(uri) found.
#
#
# The store is now: Open
# Processing reactome_xref.ttl: 100%|██████████| 14/14 [04:13<00:00, 18.12s/it]
# The store is now: Closed
# IMPORTED 5731837 TRIPLES
# True
