# %%
from biokb_chebi.db.manager import DbManager
from biokb_chebi.rdf.turtle import TurtleCreator
from biokb_chebi.rdf.neo4j_importer import Neo4jImporter
from sqlalchemy import create_engine

# %% [markdown]
# # Test the workflow with podman-compose

# %% [markdown]
# copy `.env_template` to `.env`. Never use the same passwords in production! But for testing here we use the default ones.
#
# ```bash
# podman-compose -f docker-compose.db_neo.yml up -d
# ```
#
# **Tipp:** Before running the following command, please close all other applications that might use significant system resources, as running containers can be resource-intensive.

# %%
engine = create_engine("mysql+pymysql://biokb_user:biokb_password@localhost:3306/biokb")

# DbManager(engine).import_data()
TurtleCreator(engine).create_ttls()

# %% [markdown]
# Open Neo4j [browser](http://localhost:7474), login with neo4j/neo4j_password

# %%
Neo4jImporter().import_ttls()
# Out:
# 2025-12-16 10:23:04,483 - biokb_chebi.rdf.neo4j_importer - INFO - Start importing all turtle file in Neo4J.
# 2025-12-16 10:23:04,483 - biokb_chebi.rdf.neo4j_importer - INFO - Delete an existing graph in Neo4J with node label DbChEBI.
# Uniqueness constraint on :Resource(uri) found.
#
#
# The store is now: Open
# Processing name.ttl:  25%|██▌       | 3/12 [00:12<00:36,  4.01s/it]             2025-12-16 10:24:23,801 - rdflib.term - WARNING - Failed to convert Literal lexical form to value. Datatype=http://www.w3.org/2001/XMLSchema#integer, Converter=<class 'int'>
# Traceback (most recent call last):
#   File "/home/ceb/workspace/github/biokb/biokb_chebi/.venv/lib/python3.13/site-packages/rdflib/term.py", line 2163, in _castLexicalToPython
#     return conv_func(lexical)  # type: ignore[arg-type]
# ValueError: invalid literal for int() with base 10: 'None'
# Processing reactome_xref.ttl: 100%|██████████| 12/12 [04:00<00:00, 20.05s/it]
# The store is now: Closed
# IMPORTED 5621159 TRIPLES
# True
