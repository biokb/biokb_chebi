# %%
from sqlalchemy import create_engine
from sqlalchemy.orm import sessionmaker
from biokb_chebi.db import models
from biokb_chebi.db.manager import DbManager

url = "mysql+pymysql://biokb_user:biokb_passwd@localhost:3307/biokb"
engine = create_engine(url, echo=True)
session = DbManager(engine).Session()

# %%
session.query(models.Compound).count()
# Out:
# 2025-07-01 13:25:32,617 INFO sqlalchemy.engine.Engine SELECT DATABASE()
# 2025-07-01 13:25:32,618 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-07-01 13:25:32,619 INFO sqlalchemy.engine.Engine SELECT @@sql_mode
# 2025-07-01 13:25:32,619 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-07-01 13:25:32,620 INFO sqlalchemy.engine.Engine SELECT @@lower_case_table_names
# 2025-07-01 13:25:32,620 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-07-01 13:25:32,622 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-01 13:25:32,625 INFO sqlalchemy.engine.Engine SELECT count(*) AS count_1
# FROM (SELECT chebi_compound.id AS chebi_compound_id, chebi_compound.name AS chebi_compound_name, chebi_compound.source AS chebi_compound_source, chebi_compound.chebi_accession AS chebi_compound_chebi_accession, chebi_compound.status AS chebi_compound_status, chebi_compound.definition AS chebi_compound_definition, chebi_compound.star AS chebi_compound_star, chebi_compound.modified_on AS chebi_compound_modified_on, chebi_compound.created_by AS chebi_compound_created_by, chebi_compound.parent_id AS chebi_compound_parent_id
# FROM chebi_compound) AS anon_1
# 2025-07-01 13:25:32,625 INFO sqlalchemy.engine.Engine [generated in 0.00057s] {}
# 229366
