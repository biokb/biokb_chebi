# %%
from eralchemy import render_er
from biokb_chebi.db.models import Base

## Draw from SQLAlchemy base
render_er(Base, "../docs/pics/erd_diagram.png")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 from eralchemy import render_er
# ----> 2 from biokb_chebi.db.models import Base
#       4 ## Draw from SQLAlchemy base
#       5 render_er(Base, "../docs/pics/erd_diagram.png")
#
# ModuleNotFoundError: No module named 'biokb_chebi'
