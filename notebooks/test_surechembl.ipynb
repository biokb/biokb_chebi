# %%
from numpy import row_stack
import pandas as pd

# https://ftp.ebi.ac.uk/pub/databases/chembl/SureChEMBL/bulk_data/latest/
url = "/home/ceb/Downloads/compounds.parquet"
# url = "https://ftp.ebi.ac.uk/pub/databases/chembl/SureChEMBL/bulk_data/latest/compounds.parquet"
df = pd.read_parquet(url)
print(df.head())
