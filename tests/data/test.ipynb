# %%
import pandas as pd

# %%
base_folder = "/home/ceb/.biokb/chebi/data/"
df = pd.read_csv(
    base_folder + "reference.tsv.gz",
    sep="\t",
    index_col=0,
    low_memory=False,
)

# %%
df.head()
# Out:
#          compound_id  status_id  \
# id
# 17074          40753          1
# 18922              7          1
# 21305             31          1
# 2848856           39          3
# 2851713           73          3
#
#                                                    molfile  \
# id
# 17074    \n  Marvin  01180623352D          \n\n 15 17  ...
# 18922    \n  Marvin  05100611142D          \n\n 12 13  ...
# 21305    \n  Marvin  09140616522D          \n\n 11 11  ...
# 2848856  \n  ISISHOST03240423222D 1   1.00000     0.000...
# 2851713   \n \n \n 25 30  0  0  1  0  0  0  0  0999 V20...
#
#                                                     smiles  \
# id
# 17074                                Oc1c2ccccc2cc2ccccc12
# 18922                   [H][C@@]12CC=C(C)C[C@]1([H])C2(C)C
# 21305                           CC(C)[C@H]1CC[C@H](C)CC1=O
# 2848856  [H][C@@]12CCC3=C[C@](C)(C=C)CC[C@]3([H])[C@@]1...
# 2851713  [H][C@@]12Oc3cc4c(cc3[C@]1(O)COc1c2ccc2c1OCO2)...
#
# ...

# %%
df.language_code.value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_142669/3769127366.py in ?()
# ----> 1 df.language_code.value_counts()
#
# ~/workspace/github/biokb/biokb_chebi/.venv/lib/python3.13/site-packages/pandas/core/generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'language_code'

# %%
df.isnull().sum()
# Out:
# compound_id               0
# status_id                 0
# molfile                   0
# smiles                   35
# standard_inchi        11424
# standard_inchi_key    11424
# dimension                 0
# default_structure         0
# dtype: int64
